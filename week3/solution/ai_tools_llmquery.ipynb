# %%
from ai_tools import LLMQuery

# %%
b = LLMQuery(system_prompt="You are a joke teller.")

# %%
b.query("Tell me a lame joke.", display_output=True)
# Out:
# Why don don't scientists trust atoms?
#
# Because they make up everything!
# "Why don don't scientists trust atoms?\n\nBecause they make up everything!"

# %%
# !pip install -q --upgrade bitsandbytes accelerate

# %%
from ai_tools.hugging_face import HuggingFaceQuery
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.

# %%
b = HuggingFaceQuery()
b.query("Hello, what is 3+three?")
# Out:
# Loading tokenizer for meta-llama/Llama-3.2-3B-Instruct...
# Loading model meta-llama/Llama-3.2-3B-Instruct on cuda with 4bit quantization...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# '3 + 3 = 6'

# %%
b.query_stream("Tell a long story!")
# Out:
# Once upon a time, in a small village nestled in the rolling hills of Tuscany, there lived a young girl named Sophia. Sophia was a curious and adventurous child, with a mop of curly brown hair and bright green eyes that sparkled with excitement whenever she discovered something new.
#
# Sophia lived with her parents, Giovanni and Laura, in a cozy little stone cottage on the edge of the village. Her parents were both artists, Giovanni a painter and Laura a weaver, and they spent their days creating beautiful works of art that were sought after by people from all over the region.
#
# As a child, Sophia loved to watch her parents at work, mesmerized by the way they brought their ideas to life. She would sit for hours, watching Giovanni mix colors on his palette or Laura spin threads into intricate patterns on her loom.
#
# ...

# %%
from huggingface_hub import auth_list

# %%
auth_list()
# Out:
#   name             | token
# -------------------|---------------
# * llm_engineering  | hf_****TSiF
